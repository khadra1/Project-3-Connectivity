# %%
#import dependencies 
import pandas as pd
import numpy as np

# %%
# Read the mouse data and the study results
world_data = pd.read_csv("Resources/data-raw/Data_Extract_From_World_Development_Indicators/world_bank_internet_data.csv")

# %%
world_data
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                          Afghanistan          AFG
# 3                                          Afghanistan          AFG
# 4                                          Afghanistan          AFG
# ...                                                ...          ...
# 2394                                               NaN          NaN
# 2395                                               NaN          NaN
# 2396                                               NaN          NaN
# 2397  Data from database: World Development Indicators          NaN
# 2398                          Last Updated: 05/25/2022          NaN
#
#                                            Series Name     Series Code  \
# 0     Individuals using the Internet (% of population)  IT.NET.USER.ZS
# ...

# %%
new_world_data = world_data.dropna()
new_world_data.head()
# Out:
#   Country Name Country Code                                       Series Name  \
# 0  Afghanistan          AFG  Individuals using the Internet (% of population)
# 1  Afghanistan          AFG                           Secure Internet servers
# 2  Afghanistan          AFG    Secure Internet servers (per 1 million people)
# 3  Afghanistan          AFG                     Mobile cellular subscriptions
# 4  Afghanistan          AFG    Mobile cellular subscriptions (per 100 people)
#
#       Series Code 1991 [YR1991] 1992 [YR1992] 1993 [YR1993] 1994 [YR1994]  \
# 0  IT.NET.USER.ZS             0             0             0             0
# 1     IT.NET.SECR            ..            ..            ..            ..
# 2  IT.NET.SECR.P6            ..            ..            ..            ..
# 3     IT.CEL.SETS             0             0             0             0
# 4  IT.CEL.SETS.P2             0             0             0             0
#
# ...

# %%
new_world_data.replace('..', 0).head()
# Out:
#   Country Name Country Code                                       Series Name  \
# 0  Afghanistan          AFG  Individuals using the Internet (% of population)
# 1  Afghanistan          AFG                           Secure Internet servers
# 2  Afghanistan          AFG    Secure Internet servers (per 1 million people)
# 3  Afghanistan          AFG                     Mobile cellular subscriptions
# 4  Afghanistan          AFG    Mobile cellular subscriptions (per 100 people)
#
#       Series Code 1991 [YR1991] 1992 [YR1992] 1993 [YR1993] 1994 [YR1994]  \
# 0  IT.NET.USER.ZS             0             0             0             0
# 1     IT.NET.SECR             0             0             0             0
# 2  IT.NET.SECR.P6             0             0             0             0
# 3     IT.CEL.SETS             0             0             0             0
# 4  IT.CEL.SETS.P2             0             0             0             0
#
# ...
